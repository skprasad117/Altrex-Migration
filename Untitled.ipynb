# %%
import pandas as pd

# %%
df = pd.read_csv('csv_converted\saleReprtKmpg_july - SalesReportKPMGAuditResults.csv')

# %%
df['Open Balance']
# Out:
# 0                  $0.00
# 1                  $0.00
# 2                  $0.00
# 3                  $0.00
# 4                  $0.00
#                ...
# 382143             $0.00
# 382144             $0.00
# 382145             $0.00
# 382146             $0.00
# 382147    $14,647,805.54
# Name: Open Balance, Length: 382148, dtype: object

# %%
df['Open Balance'] = df['Open Balance'].str.replace("Can","")
df['Open Balance'] = df['Open Balance'].str.replace("$","")
# Out:
# C:\Users\skpra\AppData\Local\Temp\ipykernel_23540\3981181411.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Open Balance'] = df['Open Balance'].str.replace("$","")

# %%
df[df['Open Balance']!=0]
# Out:
#         Transaction ID Document Number Transaction Type  Project ID  \
# 0              3190973       CUMC15527      Credit Memo     1277343
# 1              3169041       PCHA15338      Credit Memo      199967
# 2              3175960        UCI15467      Credit Memo      500340
# 3              3179766    IMSLLC478536          Invoice       16561
# 4              3184109       HSHS15492      Credit Memo     1611088
# ...                ...             ...              ...         ...
# 382143          589622        MPHC1341      Credit Memo      147022
# 382144          590436      LISS100813          Invoice      135186
# 382145          590707         HMA1343      Credit Memo       88328
# 382146          573756       STJHH1306      Credit Memo       91788
# 382147      2147483647   Overall Total              NaN  2147483647
#
#                                                  Customer   Terms Currency  \
# ...

# %%
l = [1,2]

# %%
l.
